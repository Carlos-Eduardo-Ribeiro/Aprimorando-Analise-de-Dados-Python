# %%
import pandas as pd 
import numpy as np
import openpyxl

# %%
dados = {
    'Time' : ['Sport', 'Santa Cruz', 'Naútico', 'São Paulo'],
    'Partidas' : [10, 10, 10, 10],
    'Vitorias' : [7, 5, 7, 9],
    'Empates': [2, 3, 5, 2],
    'Derrotas' : [12, 5, 6, 7],
    'Gols_Pro' : [2, 5, 7, 8],
    'Gols_Contra' : [23, 5, 11, 7]
    }

# %%
df = pd.DataFrame(dados)

# %%
df.head()
# Out:
#          Time  Partidas  Vitorias  Empates  Derrotas  Gols_Pro  Gols_Contra
# 0       Sport        10         7        2        12         2           23
# 1  Santa Cruz        10         5        3         5         5            5
# 2     Naútico        10         7        5         6         7           11
# 3   São Paulo        10         9        2         7         8            7

# %%
df['Vitorias'].sum().round()

df.describe()

df['Vitorias'].astype('Int64')
# Out:
# 0    7
# 1    5
# 2    7
# 3    9
# Name: Vitorias, dtype: Int64

# %%
df['Saldo_Gols'] =  df['Gols_Pro'] - df['Gols_Contra']

# %%
df.head()
# Out:
#          Time  Partidas  Vitorias  Empates  Derrotas  Gols_Pro  Gols_Contra  \
# 0       Sport        10         7        2        12         2           23
# 1  Santa Cruz        10         5        3         5         5            5
# 2     Naútico        10         7        5         6         7           11
# 3   São Paulo        10         9        2         7         8            7
#
#    Saldo_Gols
# 0         -21
# 1           0
# 2          -4
# 3           1

# %%
df["2"] = df.iloc[: , 1:].sum(axis=1)

# %%
df.head()
# Out:
#          Time  Partidas  Vitorias  Empates  Derrotas  Gols_Pro  Gols_Contra  \
# 0       Sport        10         7        2        12         2           23
# 1  Santa Cruz        10         5        3         5         5            5
# 2     Naútico        10         7        5         6         7           11
# 3   São Paulo        10         9        2         7         8            7
#
#    Saldo_Gols   2
# 0         -21  35
# 1           0  33
# 2          -4  42
# 3           1  44

# %%
df.drop(columns=['2'], inplace=True)
#or
# df.drop('2', axis=1 ,  inplace=True)

# %%
df.replace(10, np.nan)
# Out:
#          Time  Partidas  Vitorias  Empates  Derrotas  Gols_Pro  Gols_Contra  \
# 0       Sport       NaN         7        2        12         2           23
# 1  Santa Cruz       NaN         5        3         5         5            5
# 2     Naútico       NaN         7        5         6         7           11
# 3   São Paulo       NaN         9        2         7         8            7
#
#    Saldo_Gols
# 0         -21
# 1           0
# 2          -4
# 3           1

# %%
df2 = df['Vitorias'].replace(9, 20)

# %%
df3 = df.replace(df['Vitorias']==7, 20)

# %%
df3.head()
# Out:
#          Time  Partidas  Vitorias  Empates  Derrotas  Gols_Pro  Gols_Contra  \
# 0       Sport        10         7        2        12         2           23
# 1  Santa Cruz        10         5        3         5         5            5
# 2     Naútico        10         7        5         6         7           11
# 3   São Paulo        10         9        2         7         8            7
#
#    Saldo_Gols
# 0         -21
# 1           0
# 2          -4
# 3           1

# %%
df['Pontos'] = df['Vitorias'] * 3 + df['Empates']

# %%
df.head()
# Out:
#          Time  Partidas  Vitorias  Empates  Derrotas  Gols_Pro  Gols_Contra  \
# 0       Sport        10         7        2        12         2           23
# 1  Santa Cruz        10         5        3         5         5            5
# 2     Naútico        10         7        5         6         7           11
# 3   São Paulo        10         9        2         7         8            7
#
#    Saldo_Gols  Pontos
# 0         -21      23
# 1           0      18
# 2          -4      26
# 3           1      29

# %%
df.sort_values(by='Vitorias', ascending=False, inplace=True)

# %%
df.to_excel(r'../dados/excel.xlsx', index=False)
